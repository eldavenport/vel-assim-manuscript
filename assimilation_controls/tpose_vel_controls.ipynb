# %%
import matplotlib.pyplot as plt
import cmocean.cm as cmo
from mitgcm_assim.ctrls import load_controls_and_sensitivities

sep_data_dir = '/data/SO3/edavenport/tpose6/sep2012/velocity_assim/run_ad'
nov_data_dir = '/data/SO3/edavenport/tpose6/nov2012/run_iter20'
jan_data_dir = '/data/SO3/edavenport/tpose6/jan2013/run_iter14'
mar_data_dir = '/data/SO3/edavenport/tpose6/mar2013/run_iter16'

grid_dir = '/data/SO6/TPOSE_diags/tpose6/grid_6/'

sep_final_iter = 22
nov_final_iter = 20
jan_final_iter = 14
mar_final_iter = 16 

folder_name = 'assimilation_controls/'

# Load all control variables and sensitivities into a Dataset
# This automatically loads grid information and applies proper MITgcm coordinate names
ds_sep = load_controls_and_sensitivities(sep_data_dir, grid_dir, sep_final_iter)
ds_nov = load_controls_and_sensitivities(nov_data_dir, grid_dir, nov_final_iter)
ds_jan = load_controls_and_sensitivities(jan_data_dir, grid_dir, jan_final_iter)
ds_mar = load_controls_and_sensitivities(mar_data_dir, grid_dir, mar_final_iter)
# Out:
# /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/xmitgcm/mds_store.py:289: FutureWarning: In a future version, xarray will not decode the variable 'time' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds['time'] = xr.decode_cf(ds[['time']])['time']
# /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/xmitgcm/mds_store.py:289: FutureWarning: In a future version, xarray will not decode the variable 'time' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds['time'] = xr.decode_cf(ds[['time']])['time']
# Warning: Could not load adxx_theta: No files found for /data/SO3/edavenport/tpose6/nov2012/run_iter20/adxx_theta.0000000020.meta
# Warning: Could not load adxx_salt: No files found for /data/SO3/edavenport/tpose6/nov2012/run_iter20/adxx_salt.0000000020.meta
# Warning: Could not load adxx_uwind: No files found for /data/SO3/edavenport/tpose6/nov2012/run_iter20/adxx_uwind.0000000020.meta
# Warning: Could not load adxx_vwind: No files found for /data/SO3/edavenport/tpose6/nov2012/run_iter20/adxx_vwind.0000000020.meta
# Warning: Could not load adxx_atemp: No files found for /data/SO3/edavenport/tpose6/nov2012/run_iter20/adxx_atemp.0000000020.meta
# Warning: Could not load adxx_aqh: No files found for /data/SO3/edavenport/tpose6/nov2012/run_iter20/adxx_aqh.0000000020.meta
# Warning: Could not load adxx_lwdown: No files found for /data/SO3/edavenport/tpose6/nov2012/run_iter20/adxx_lwdown.0000000020.meta
# Warning: Could not load adxx_precip: No files found for /data/SO3/edavenport/tpose6/nov2012/run_iter20/adxx_precip.0000000020.meta
# Warning: Could not load adxx_swdown: No files found for /data/SO3/edavenport/tpose6/nov2012/run_iter20/adxx_swdown.0000000020.meta
# Warning: Could not load adxx_vvel: No files found for /data/SO3/edavenport/tpose6/nov2012/run_iter20/adxx_vvel.0000000020.meta
# Warning: Could not load adxx_uvel: No files found for /data/SO3/edavenport/tpose6/nov2012/run_iter20/adxx_uvel.0000000020.meta
# /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/xmitgcm/mds_store.py:289: FutureWarning: In a future version, xarray will not decode the variable 'time' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds['time'] = xr.decode_cf(ds[['time']])['time']
# Warning: Could not load adxx_theta: No files found for /data/SO3/edavenport/tpose6/jan2013/run_iter14/adxx_theta.0000000014.meta
# Warning: Could not load adxx_salt: No files found for /data/SO3/edavenport/tpose6/jan2013/run_iter14/adxx_salt.0000000014.meta
# Warning: Could not load adxx_uwind: No files found for /data/SO3/edavenport/tpose6/jan2013/run_iter14/adxx_uwind.0000000014.meta
# Warning: Could not load adxx_vwind: No files found for /data/SO3/edavenport/tpose6/jan2013/run_iter14/adxx_vwind.0000000014.meta
# Warning: Could not load adxx_atemp: No files found for /data/SO3/edavenport/tpose6/jan2013/run_iter14/adxx_atemp.0000000014.meta
# Warning: Could not load adxx_aqh: No files found for /data/SO3/edavenport/tpose6/jan2013/run_iter14/adxx_aqh.0000000014.meta
# Warning: Could not load adxx_lwdown: No files found for /data/SO3/edavenport/tpose6/jan2013/run_iter14/adxx_lwdown.0000000014.meta
# Warning: Could not load adxx_precip: No files found for /data/SO3/edavenport/tpose6/jan2013/run_iter14/adxx_precip.0000000014.meta
# Warning: Could not load adxx_swdown: No files found for /data/SO3/edavenport/tpose6/jan2013/run_iter14/adxx_swdown.0000000014.meta
# Warning: Could not load adxx_vvel: No files found for /data/SO3/edavenport/tpose6/jan2013/run_iter14/adxx_vvel.0000000014.meta
# Warning: Could not load adxx_uvel: No files found for /data/SO3/edavenport/tpose6/jan2013/run_iter14/adxx_uvel.0000000014.meta
# /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/xmitgcm/mds_store.py:289: FutureWarning: In a future version, xarray will not decode the variable 'time' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds['time'] = xr.decode_cf(ds[['time']])['time']
# Warning: Could not load adxx_theta: No files found for /data/SO3/edavenport/tpose6/mar2013/run_iter16/adxx_theta.0000000016.meta
# Warning: Could not load adxx_salt: No files found for /data/SO3/edavenport/tpose6/mar2013/run_iter16/adxx_salt.0000000016.meta
# Warning: Could not load adxx_uwind: No files found for /data/SO3/edavenport/tpose6/mar2013/run_iter16/adxx_uwind.0000000016.meta
# Warning: Could not load adxx_vwind: No files found for /data/SO3/edavenport/tpose6/mar2013/run_iter16/adxx_vwind.0000000016.meta
# Warning: Could not load adxx_atemp: No files found for /data/SO3/edavenport/tpose6/mar2013/run_iter16/adxx_atemp.0000000016.meta
# Warning: Could not load adxx_aqh: No files found for /data/SO3/edavenport/tpose6/mar2013/run_iter16/adxx_aqh.0000000016.meta
# Warning: Could not load adxx_lwdown: No files found for /data/SO3/edavenport/tpose6/mar2013/run_iter16/adxx_lwdown.0000000016.meta
# Warning: Could not load adxx_precip: No files found for /data/SO3/edavenport/tpose6/mar2013/run_iter16/adxx_precip.0000000016.meta
# Warning: Could not load adxx_swdown: No files found for /data/SO3/edavenport/tpose6/mar2013/run_iter16/adxx_swdown.0000000016.meta
# Warning: Could not load adxx_vvel: No files found for /data/SO3/edavenport/tpose6/mar2013/run_iter16/adxx_vvel.0000000016.meta
# Warning: Could not load adxx_uvel: No files found for /data/SO3/edavenport/tpose6/mar2013/run_iter16/adxx_uvel.0000000016.meta
