# %%
import copernicusmarine

# Replace with your CMEMS credentials
USERNAME = "user_name"
PASSWORD = "user_password"

DATASET_ID = "cmems_obs-sl_glo_phy-ssh_my_allsat-l4-duacs-0.125deg_P1D"

# Define your domain for the Equatorial Pacific
# Example: 180W to 90W, 10S to 10N
copernicusmarine.subset(
    dataset_id=DATASET_ID,
    variables=["sla", "adt"],
    start_datetime="2010-01-01T00:00:00",
    end_datetime="2020-12-31T23:59:59",
    minimum_longitude=-180,
    maximum_longitude=-90,
    minimum_latitude=-10,
    maximum_latitude=10,
    output_directory="aviso_data",
    output_filename="aviso_equatorial_pacific.nc",
    username=USERNAME,
    password=PASSWORD
)
# Out:
# INFO - 2026-04-01T17:53:16Z - Selected dataset version: "202411"
# INFO - 2026-04-01T17:53:16Z - Selected dataset part: "default"
# WARNING - 2026-04-01T17:53:16Z - Some of your subset selection [-180.0, -90.0] for the longitude dimension exceed the dataset coordinates [-179.9375, 179.9375]
# 100%|██████████| 262/262 [02:41<00:00,  1.62it/s]
# ...
