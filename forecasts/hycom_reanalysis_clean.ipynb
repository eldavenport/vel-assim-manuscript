# %% [markdown]
# # HYCOM 2013 Reanalysis Download
#
# notebook to download HYCOM reanalysis data for 2013

# %%
from forecasts.hycom_download import download_hycom_2013_fast

# Download HYCOM 2013 data with aggressive chunking for speed
# Domain: 180W-90W, 10S-10N, 0-500m depth
# Downloads 6-month chunks to maximize speed
output_dir = download_hycom_2013_fast(output_dir='forecasts/hycom_data')
print(f"Data saved to: {output_dir}")
